# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("train.csv") 
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %% [markdown]
# Understand missing Values, write a function that will print out the percentage of each columns missing values for the whole dataset(compared with the rows of the whole dataset)

# %%
def nan_percentage(dataset):
    nan_count = dataset.isnull().sum()
    all_rows = len(dataset)
    nan_perc = (nan_count / all_rows) * 100
    for column,percentage in nan_perc.items():
        print(f"{column}: {percentage}%")
print(nan_percentage(data))
# Out:
# Id: 0.0%
# MSSubClass: 0.0%
# MSZoning: 0.0%
# LotFrontage: 17.73972602739726%
# LotArea: 0.0%
# Street: 0.0%
# Alley: 93.76712328767123%
# LotShape: 0.0%
# LandContour: 0.0%
# Utilities: 0.0%
# LotConfig: 0.0%
# LandSlope: 0.0%
# Neighborhood: 0.0%
# Condition1: 0.0%
# Condition2: 0.0%
# BldgType: 0.0%
# HouseStyle: 0.0%
# OverallQual: 0.0%
# OverallCond: 0.0%
# YearBuilt: 0.0%
# YearRemodAdd: 0.0%
# RoofStyle: 0.0%
# RoofMatl: 0.0%
# Exterior1st: 0.0%
# Exterior2nd: 0.0%
# MasVnrType: 0.547945205479452%
# MasVnrArea: 0.547945205479452%
# ExterQual: 0.0%
# ExterCond: 0.0%
# Foundation: 0.0%
# BsmtQual: 2.5342465753424657%
# BsmtCond: 2.5342465753424657%
# BsmtExposure: 2.6027397260273974%
# BsmtFinType1: 2.5342465753424657%
# BsmtFinSF1: 0.0%
# BsmtFinType2: 2.6027397260273974%
# BsmtFinSF2: 0.0%
# BsmtUnfSF: 0.0%
# TotalBsmtSF: 0.0%
# Heating: 0.0%
# HeatingQC: 0.0%
# CentralAir: 0.0%
# Electrical: 0.0684931506849315%
# 1stFlrSF: 0.0%
# 2ndFlrSF: 0.0%
# LowQualFinSF: 0.0%
# GrLivArea: 0.0%
# BsmtFullBath: 0.0%
# BsmtHalfBath: 0.0%
# FullBath: 0.0%
# HalfBath: 0.0%
# BedroomAbvGr: 0.0%
# KitchenAbvGr: 0.0%
# KitchenQual: 0.0%
# TotRmsAbvGrd: 0.0%
# Functional: 0.0%
# Fireplaces: 0.0%
# FireplaceQu: 47.26027397260274%
# GarageType: 5.5479452054794525%
# GarageYrBlt: 5.5479452054794525%
# GarageFinish: 5.5479452054794525%
# GarageCars: 0.0%
# GarageArea: 0.0%
# GarageQual: 5.5479452054794525%
# GarageCond: 5.5479452054794525%
# PavedDrive: 0.0%
# WoodDeckSF: 0.0%
# OpenPorchSF: 0.0%
# EnclosedPorch: 0.0%
# 3SsnPorch: 0.0%
# ScreenPorch: 0.0%
# PoolArea: 0.0%
# PoolQC: 99.52054794520548%
# Fence: 80.75342465753424%
# MiscFeature: 96.30136986301369%
# MiscVal: 0.0%
# MoSold: 0.0%
# YrSold: 0.0%
# SaleType: 0.0%
# SaleCondition: 0.0%
# SalePrice: 0.0%
# None

# %%
data.isna().any()
# Out:
# Id               False
# MSSubClass       False
# MSZoning         False
# LotFrontage       True
# LotArea          False
#                  ...
# MoSold           False
# YrSold           False
# SaleType         False
# SaleCondition    False
# SalePrice        False
# Length: 81, dtype: bool

# %% [markdown]
# Filter out all The Numerical Variables understand the correlation between numerical columns

# %%
num_cols = data.select_dtypes(include=['int64', 'float64'])
corr = num_cols.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# C:\Users\Arman\AppData\Local\Temp\ipykernel_12464\2705182418.py:3: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T
{
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_0b6b4_row0_col18, #T_0b6b4_row0_col20, #T_0b6b4_row0_col33, #T_0b6b4_row1_col21, #T_0b6b4_row2_col31, #T_0b6b4_row8_col10, #T_0b6b4_row9_col20, #T_0b6b4_row10_col37, #T_0b6b4_row15_col7, #T_0b6b4_row16_col18, #T_0b6b4_row18_col27, #T_0b6b4_row19_col10, #T_0b6b4_row19_col36, #T_0b6b4_row26_col18, #T_0b6b4_row26_col22, #T_0b6b4_row31_col21, #T_0b6b4_row32_col22, #T_0b6b4_row32_col23, #T_0b6b4_row34_col24, #T_0b6b4_row36_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_0b6b4_row0_col19, #T_0b6b4_row5_col36, #T_0b6b4_row10_col15, #T_0b6b4_row14_col3, #T_0b6b4_row15_col12, #T_0b6b4_row16_col10, #T_0b6b4_row18_col3, #T_0b6b4_row21_col35, #T_0b6b4_row22_col16, #T_0b6b4_row24_col35, #T_0b6b4_row30_col21, #T_0b6b4_row32_col16, #T_0b6b4_row33_col7, #T_0b6b4_row37_col35 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_0b6b4_row0_col21, #T_0b6b4_row3_col29, #T_0b6b4_row15_col19, #T_0b6b4_row15_col22, #T_0b6b4_row22_col15, #T_0b6b4_row26_col35, #T_0b6b4_row27_col5, #T_0b6b4_row28_col18, #T_0b6b4_row29_col28, #T_0b6b4_row31_col27, #T_0b6b4_row32_col3, #T_0b6b4_row35_col10, #T_0b6b4_row35_col37, #T_0b6b4_row37_col10 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_0b6b4_row0_col22, #T_0b6b4_row3_col15, #T_0b6b4_row7_col36, #T_0b6b4_row10_col32, #T_0b6b4_row11_col35, #T_0b6b4_row13_col32, #T_0b6b4_row14_col35, #T_0b6b4_row21_col10, #T_0b6b4_row23_col35, #T_0b6b4_row27_col10, #T_0b6b4_row31_col18, #T_0b6b4_row31_col37, #T_0b6b4_row32_col18, #T_0b6b4_row35_col18 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_0b6b4_row0_col25, #T_0b6b4_row3_col4, #T_0b6b4_row10_col6, #T_0b6b4_row17_col30, #T_0b6b4_row21_col15, #T_0b6b4_row24_col1, #T_0b6b4_row28_col14, #T_0b6b4_row31_col13, #T_0b6b4_row32_col6, #T_0b6b4_row36_col25 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_0b6b4_row0_col27, #T_0b6b4_row0_col35, #T_0b6b4_row6_col23, #T_0b6b4_row7_col35, #T_0b6b4_row15_col6, #T_0b6b4_row17_col29, #T_0b6b4_row18_col28, #T_0b6b4_row20_col10, #T_0b6b4_row24_col33, #T_0b6b4_row28_col35, #T_0b6b4_row28_col36, #T_0b6b4_row29_col32, #T_0b6b4_row31_col10, #T_0b6b4_row31_col14, #T_0b6b4_row32_col35, #T_0b6b4_row33_col18, #T_0b6b4_row36_col14, #T_0b6b4_row36

# %% [markdown]
# Distribution of the Numerical Variables you want to explore

# %%
num_cols.hist(bins=20, figsize=(22, 20))
plt.show()

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# Outliers (use boxplot,or numpy precentiles function to find out)

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=num_cols)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Relationship between independent(all columns except SalePrice) and dependent feature(SalePrice)

# %%
y = data['SalePrice']
x = data.drop('SalePrice', axis=1)
corr_x = x.corrwith(y)
plt.figure(figsize=(16, 12))
corr_sorted = corr_x.sort_values(ascending=False)
sns.barplot(x=corr_sorted.values, y=corr_sorted.index) 
plt.xlabel('Correlation with SalePrice')
plt.ylabel('Features')
plt.title('Correlation between Independent Variables and SalePrice')
plt.show()
# Out:
# C:\Users\Arman\AppData\Local\Temp\ipykernel_12464\3661629410.py:3: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_x = x.corrwith(y)
